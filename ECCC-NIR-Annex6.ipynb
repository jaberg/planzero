# %% [markdown]
# # Raw Tables

# %%
import planzero.eccc_nir_annex6
planzero.eccc_nir_annex6.df_a6_1_1
# Out:
#     Year  Canada    BC    AB    SK    MB    QC    NB    ON    NS    PE    NL  \
# 0   1990    1899  1926  1928  1829  1886  1887  1888  1901  1901  1901  1901
# 1   1995    1899  1926  1928  1829  1886  1887  1888  1901  1901  1901  1901
# 2   2000    1895  1918  1923  1839  1880  1880  1881  1884  1884  1884  1884
# 3   2005    1883  1898  1911  1864  1864  1864  1865  1864  1864  1864  1867
# 4   2006    1878  1896  1917  1855  1855  1854  1855  1855  1855  1855  1862
# 5   2007    1881  1901  1910  1857  1857  1858  1859  1858  1858  1858  1856
# 6   2008    1887  1906  1910  1863  1863  1865  1865  1864  1864  1864  1860
# 7   2009    1889  1900  1920  1861  1861  1865  1863  1862  1862  1862  1865
# 8   2010    1891  1902  1923  1860  1862  1868  1869  1865  1865  1865  1864
# 9   2011    1893  1900  1921  1866  1866  1870  1871  1869  1869  1869  1869
# 10  2012    1905  1899  1931  1874  1873  1882  1888  1880  1880  1880  1873
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_2
# Out:
#     Year    BC    AB    SK    MB  QC    ON    NB    NS  PE      NL    YT  \
# 0   1990  2162  2080  2441  2401 NaN  2401  2401  2494 NaN     NaN  2401
# 1   1995  2162  2080  2441  2401 NaN  2401  2401  2494 NaN     NaN  2401
# 2   2000  2162  2080  2441  2401 NaN  2401  2401  2494 NaN     NaN  2401
# 3   2005  2162  2080  2441  2401 NaN  2401  2401  2494 NaN  2299.0  2401
# 4   2006  2162  2080  2441  2401 NaN  2401  2401  2494 NaN  2298.0  2401
# 5   2007  2162  2080  2441  2401 NaN  2401  2401  2494 NaN  2294.0  2401
# 6   2008  2162  2080  2441  2401 NaN  2401  2401  2494 NaN  2327.0  2401
# 7   2009  2162  2080  2441  2401 NaN  2401  2401  2494 NaN  2309.0  2401
# 8   2010  2162  2054  2441  2401 NaN  2401  2401  2494 NaN  2276.0  2401
# 9   2011  2162  2062  2441  2401 NaN  2401  2401  2494 NaN  2220.0  2401
# 10  2012  2162  2068  2441  2401 NaN  2401  2401  2494 NaN  2281.0  2401
# 11  2013  2162  2071  2441  2401 NaN  2401  2401  2494 NaN  2272.0  2401
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_3
# Out:
#                               Emission Factor Source  CH4 (g/m3)  N2O (g/m3)
# 0                                 Electric Utilities       0.490       0.049
# 1                                         Industrial       0.037       0.033
# 2              Producer Consumption (Non-marketable)       6.400       0.060
# 3  Producer Consumption (Non-marketable) - Newfou...       0.490       0.060
# 4                                          Pipelines       1.900       0.050
# 5                                             Cement       0.037       0.034
# 6                           Manufacturing Industries       0.037       0.033
# 7  Residential, Construction, Commercial/Institut...       0.037       0.035

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_4
# Out:
#     Year    BC    AB    SK
# 0   1990  8.85  6.40  6.02
# 1   1991  8.85  6.40  6.42
# 2   1992  8.85  6.40  6.29
# 3   1993  8.85  6.40  5.99
# 4   1994  8.85  6.40  5.71
# 5   1995  8.85  6.40  5.54
# 6   1996  8.85  6.62  5.30
# 7   1997  8.85  6.85  5.18
# 8   1998  8.85  7.07  5.29
# 9   1999  8.85  7.29  5.19
# 10  2000  8.85  7.52  5.04
# 11  2001  8.85  7.74  5.26
# 12  2002  8.87  7.96  5.44
# 13  2003  8.79  8.19  5.78
# 14  2004  9.15  8.41  4.90
# 15  2005  9.15  8.51  4.66
# 16  2006  9.15  8.50  4.77
# 17  2007  9.15  8.52  4.67
# 18  2008  9.04  8.55  4.55
# 19  2009  9.03  8.51  4.44
# 20  2010  8.91  8.52  4.10
# 21  2011  8.80  8.58  3.80
# 22  2012  8.66  8.32  3.60
# 23  2013  8.59  8.33  3.44
# 24  2014  8.61  8.32  4.04
# 25  2015  8.41  8.22  3.81
# 26  2016  8.47  8.32  3.89
# 27  2017  8.39  8.39  3.89
# 28  2018  8.41  8.25  4.16
# 29  2019  8.44  8.16  4.55
# 30  2020  8.59  8.23  4.82
# 31  2021  8.73  8.07  4.49
# 32  2022  8.83  8.21  4.09
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_5
# Out:
#                      Source  CO2 (g/L)  CH4 (g/L)  N2O (g/L)
# 0     Propane - Residential       1515     0.0276     0.1086
# 1  Propane - All Other Uses       1515     0.0246     0.1080
# 2                    Ethane        986     0.0246     0.1080
# 3                    Butane       1747     0.0240     0.1080

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_6
# Out:
#          Fuel Type                                             Sector  \
# 0   Light Fuel Oil                                 Electric Utilities
# 1   Light Fuel Oil                                         Industrial
# 2   Light Fuel Oil                               Producer Consumption
# 3   Light Fuel Oil                                        Residential
# 4   Light Fuel Oil  Forestry, Construction, Public Admin, Commerci...
# 5   Heavy Fuel Oil                                 Electric Utilities
# 6   Heavy Fuel Oil                                         Industrial
# 7   Heavy Fuel Oil                               Producer Consumption
# 8   Heavy Fuel Oil  Residential, Forestry, Construction, Public Ad...
# 9         Kerosene                                 Electric Utilities
# 10        Kerosene                                         Industrial
# 11        Kerosene                               Producer Consumption
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_7
# Out:
#     Year  Petroleum Coke - Upgrading Facilities (g/L)  \
# 0   1990                                         2965
# 1   1995                                         2961
# 2   2000                                         2903
# 3   2005                                         2837
# 4   2006                                         2813
# 5   2007                                         2800
# 6   2008                                         2813
# 7   2009                                         2792
# 8   2010                                         2817
# 9   2011                                         2820
# 10  2012                                         2802
# 11  2013                                         2765
# 12  2014                                         2794
# 13  2015                                         2795
# 14  2016                                         2781
# 15  2017                                         2800
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_8
# Out:
#     Year  Upgrading Facilities (g/m3)  Refineries and Others (g/m3)
# 0   1990                         18.2                          21.9
# 1   1995                         18.9                          22.9
# 2   2000                         20.1                          23.5
# 3   2005                         19.5                          23.0
# 4   2006                         19.4                          23.1
# 5   2007                         19.3                          23.1
# 6   2008                         19.4                          23.1
# 7   2009                         19.2                          23.2
# 8   2010                         19.4                          23.2
# 9   2011                         19.4                          23.2
# 10  2012                         19.3                          23.4
# 11  2013                         19.0                          23.4
# 12  2014                         19.2                          23.4
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_9
# Out:
#     Year  CH4 Emission Factor (g/m^3)
# 0   1990                        0.033
# 1   1991                        0.033
# 2   1992                        0.033
# 3   1993                        0.033
# 4   1994                        0.033
# 5   1995                        0.033
# 6   1996                        0.033
# 7   1997                        0.032
# 8   1998                        0.031
# 9   1999                        0.033
# 10  2000                        0.034
# 11  2001                        0.034
# 12  2002                        0.033
# 13  2003                        0.033
# 14  2004                        0.033
# 15  2005                        0.032
# 16  2006                        0.032
# 17  2007                        0.032
# 18  2008                        0.032
# 19  2009                        0.032
# 20  2010                        0.032
# 21  2011                        0.033
# 22  2012                        0.031
# 23  2013                        0.031
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_10
# Out:
#                 Province/Territory             Coal Type & Source  \
# 0   NL, NS, PE, QC (Prior to 2000)       Canadian Bituminous (NS)
# 1     NL, NS, PE, QC (2000 onward)       Canadian Bituminous (AB)
# 2               NB (Prior to 2010)       Canadian Bituminous (NB)
# 3                 NB (2010 onward)       Canadian Bituminous (AB)
# 4               AB, BC, MB, ON, SK       Canadian Bituminous (AB)
# 5                NB, NS, PE and NL  Foreign Bituminous (Non-U.S.)
# 6                               MB   Foreign Bituminous (U.S. PA)
# 7                               ON   Foreign Bituminous (U.S. PA)
# 8                       QC, AB, BC   Foreign Bituminous (U.S. PA)
# 9         All Prov/Terr, except SK                   Lignite (SK)
# 10                              SK                   Lignite (SK)
# 11                      QC, ON, MB       Sub-bituminous (Foreign)
# 12                          NS, PE       Sub-bituminous (Foreign)
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_11
# Out:
#   Coal Product - Fuel Type  Emission Factor Units    Data Source
# 0            Coke Oven Gas              687  g/m³  McCann (2000)
# 1                     Coke             3173  g/kg     CRA (2014)

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_12
# Out:
#                                       Source  CH4 Emission Factor  \
# 0                  Coal - Electric Utilities                 0.02
# 1    Coal - Industry and Heat & Steam Plants                 0.03
# 2  Coal - Residential, Public Administration                 4.00
# 3                                       Coke                 0.03
# 4                              Coke Oven Gas                 0.04
#
#    N2O Emission Factor Units
# 0                 0.03  g/kg
# 1                 0.02  g/kg
# 2                 0.02  g/kg
# 3                 0.02  g/kg
# 4                 0.04  g/m3

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_13
# Out:
#     Year  Bituminous - AB  Bituminous - BC  Bituminous - NS  \
# 0   1990             0.58             0.82              NaN
# 1   1995             0.58             0.82             0.07
# 2   2000             0.59             0.82             0.07
# 3   2005             0.51             0.87             0.07
# 4   2006             0.48             0.86             0.07
# 5   2007             0.47             0.87              NaN
# 6   2008             0.47             0.85              NaN
# 7   2009             0.43             0.85              NaN
# 8   2010             0.44             0.86              NaN
# 9   2011             0.42             0.84              NaN
# 10  2012             0.45             0.85              NaN
# 11  2013             0.46             0.84              NaN
# 12  2014             0.52             0.84              NaN
# 13  2015             0.55             0.86              NaN
# 14  2016              NaN             0.87              NaN
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_14
# Out:
#     Year  CO2 (kg/GJ)  CH4 (kg/GJ)  N2O (kg/GJ)
# 0   1990         78.8         0.03        0.004
# 1   1995         77.6         0.03        0.004
# 2   2000         77.6         0.03        0.004
# 3   2005         81.1         0.03        0.004
# 4   2006         79.4         0.03        0.004
# 5   2007         80.1         0.03        0.004
# 6   2008         79.5         0.03        0.004
# 7   2009         78.2         0.03        0.004
# 8   2010         79.3         0.03        0.004
# 9   2011         79.1         0.03        0.004
# 10  2012         79.1         0.03        0.004
# 11  2013         79.1         0.03        0.004
# 12  2014         79.1         0.03        0.004
# 13  2015         79.1         0.03        0.004
# 14  2016         79.1         0.03        0.004
# 15  2017         88.7         0.03        0.004
# 16  2018         83.0         0.03        0.004
# 17  2019         88.9         0.03        0.004
# 18  2020         68.5         0.03        0.004
# ...

# %%
import importlib
planzero.eccc_nir_annex6 = importlib.reload(planzero.eccc_nir_annex6)
planzero.eccc_nir_annex6.df_a6_1_15
# Out:
#                Mode                              Category  \
# 0    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 1    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 2    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 3    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 4    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 5    Road Transport  Light-duty Gasoline Vehicles (LDGVs)
# 6    Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 7    Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 8    Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 9    Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 10   Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 11   Road Transport    Light-duty Gasoline Trucks (LDGTs)
# 12   Road Transport  Heavy-duty Gasoline Vehicles (HDGVs)
# 13   Road Transport  Heavy-duty Gasoline Vehicles (HDGVs)
# 14   Road Transport  Heavy-duty Gasoline Vehicles (HDGVs)
# ...
